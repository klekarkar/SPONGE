# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1) Define catchment & wetland fraction
# Parameters (from your trapezoid geometry)
catchment_area_ha = 350.0
catchment_area_m2 = catchment_area_ha * 1e4
wetland_frac     = 0.10
wetland_area     = catchment_area_m2 * wetland_frac

b_top    = 500.0   # top width [m]
L_top = wetland_area / b_top  # length [m]
m     = 3.0     # side slope [horizontal per unit vertical]
h_max = 1.50    # max depth [m]
b_bot = b_top - 2*m*h_max
L_bot = L_top - 2*m*h_max


def V_trap(h, b_bot, L_bot, m):
    A_bot = b_bot * L_bot
    A_top = (b_bot + 2*m*h) * (L_bot + 2*m*h)
    return 0.5 * h * (A_bot + A_top)

# %%
# Depth array
h = np.linspace(0, h_max, 100)  # depths from 0 to max

# Cross‐sectional area (m²) and volume (m³)
vol = V_trap(h, b_bot, L_bot, m)  # volume as a function of depth

# Plot volume vs. depth
plt.figure(figsize=(8, 5))
plt.plot(h, V, linewidth=2)
plt.xlabel('Water Depth h (m)')
plt.ylabel('Pond Volume V (m³)')
plt.title('Wetland Pond Volume vs. Depth')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Plot volume vs. depth
#       8 plt.figure(figsize=(8, 5))
# ----> 9 plt.plot(h, V, linewidth=2)
#      10 plt.xlabel('Water Depth h (m)')
#      11 plt.ylabel('Pond Volume V (m³)')
#
# NameError: name 'V' is not defined
